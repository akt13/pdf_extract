# %%
from tabula import read_pdf, convert_into

pdf_file="22972_Form 16_2021-22.pdf"
#list all tables
tables = read_pdf(pdf_file, pages='all',password='BCZPT7096P20111996')

# print(tables)
# tables.to_csv('pdfTOexcel.xlsx')

for table in tables:
    print(type(tables))
    print(tables)
    break
    #remove Nan columns
#     table = table.dropna(axis="columns")
#     table.to_csv(f'pdfTOcsv.csv')
#     if not table.empty:
#         print(f"Table {table_number}")
#         print(table)

#         convert the table dataframe into csv file
#         

#         table_number += 1
#
# Out:
# <class 'list'>
# [                                         FORM NO. 16  \
# 0                                [See rule 31(1)(a)]
# 1                                             PART A
# 2  Certificate under Section 203 of the Income-ta...
# 3                             Certificate No.FHOLEEA
# 4                   Name and address of the Employer
#
#                          Unnamed: 0
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3        Last updated on17-Jun-2021
# 4  Name and address of the Employee  ,                                  PAN of the Deductor  \
# 0                                                NaN
# 1                                          CIT (TDS)
# 2                                                NaN
# 3  Summary of amount paid/credited and tax deduct...
# 4                                         Quarter(s)
# 5                                                 Q1
# ...
